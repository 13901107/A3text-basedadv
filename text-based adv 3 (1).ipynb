# %%
# mountain path
def mountain_path():

# coast path. continued
 def coast_path2():
  print("\nHe raises his eyebrow saying, “If you must know, these tattoos are representative of the many places I have traversed, for my people, for the many people I will meet and for the ever-expanding sea of knowledge.”")
  print("He smiles, and chuckles to himself.")
  print("Will you ask him to join your party? (1 or 2)")
  print("1). Yes.")
  print("2). No.")

  # take input()
  answer = input(">")
  
if answer == "1":
    # coast_path will continue with more dialogue
    # regardless of which answer is chosen the mountain_path will be reached
    mountain_path("Hearing how he shares your spirit you extend a hand to his.\nHe shakes your hand firmly, saluting his chest, “Gladly adventurer.” \n'\033[36m' + 'Killian' + '\033[36m''\033[0m' 'the' '\033[1m' + 'Monk' + '\033[0m' 'has joined your party!')\
  elif answer == "2":
    mountain_path("You decide to let him roam the world on his lonesome and bid him farewell.")
  else:
    # call try_again() with "reason"
    try_again("Don't be silly adventurer, once more!")

# coast path. continued
def coast_path1():
  print("\nChuckling to yourself you continue along the crashing waves, drinking in the day’s sunlight.")
  print("You encounter a deep-blue skinned man (of sorts) sitting on a boulder, his fins fluttering around the dark ink on his limbs.")
  print("Poised, and meditative.")
  print("Will you ask him about his tattoos? (1 or 2)")
  print("1). Yes.")
  print("2). No.")

  # take input()
  answer = input(">")
  
  if answer == "1":
    # coast_path will continue with more dialogue
    coast_path2("You introduce yourself, and his green eyes reflect yours as he narrows his eyes.")
  elif answer == "2":
    # regardless of which answer is chosen coast_path1 will be reached
    print("You take your fill of his intricate inks and pass by him without an utterance.")
    coast_path2()
  else:
    # call try_again() with "reason"
    try_again("Don't be silly adventurer, once more!")

# city path. continued.
def city_path1():
  # continuing on the way to the city_path for additional dialogue to appear
  print("\nYou hear a rustling approach.")
  print("A horned woman emerges from within the dark, cloaked in vermillion she speaks sharply.\n“Have you seen my bracelet, adventurer?” She observes you, eye to eye.")
  print("\nYou answer: (1 or 2)")
  print("1). Yes.")
  print("2). No.")

  # take input()
  answer = input(">")
  
  if answer == "1":
    # both options will lead to the city_path but! 
    # there is the opportunity to have the 'cleric' join the party
    print("Her golden eyes lock with the bracelet.")
    print("She huffs and you feel oddly refreshed.\nThe bracelet clinks onto her wrist and a sigh of relief escapes her.\nYou beckon her to your side and she nods solemnly.")
    city_path1('\033[93m' + 'Penelope' + '\033[93m' '\033[0m' "the" '\033[1m' + 'Cleric' + '\033[0m' "has joined your party!")
  elif answer == "2":
    # the cleric does NOT joint the party
    # player continues on their journey
    print("Shaking your head with a fervent no.\nShe regards you coldly snarling, with a spin of her cloak she is gone.")
    city_path1()
  else:
    # call try_again() with "reason"
    try_again("Don't be silly adventurer, once more!")
    
# coast path
def coast_path():
  # some prompts
  print("\nAs you travel along the forest you emerge from the thicket to the scent of salty air.")
  print("The coast, a quick detour and to cool your feet.")
  print("Water lapping at your ankles you close your eyes and listen to the cry of seagulls.")
  print("You sense a prickly gaze on your back, do you open your eyes? (1 or 2)")
  print("1). Yes.")
  print("2). No.")

  # take input()
  answer = input(">")
  
  if answer == "1":
    # coast_path will continue with more dialogue
    coast_path1("You open your eyes, and nothing appears out of the ordinary.")
  elif answer == "2":
    # regardless of which answer is chosen coast_path1 will be reached
    print("You keep your eyes closed. The feeling will go away, surely.")
    coast_path1()
  else:
    # call try_again() with "reason"
    try_again("Don't be silly adventurer, once more!")

# city path
def city_path():
  # continuing on the way to the city_path for additional dialogue to appear
  print("\nYou hear a rustling approach.")
  print("A horned woman emerges from within the dark, cloaked in vermillion she speaks sharply.\n“Have you seen my bracelet, adventurer?” She observes you, eye to eye.\nYou answer:")
  print("1). Yes.")
  print("2). No.")

  # take input()
  answer = input(">")
  
  if answer == "1":
    # both options will lead to the city_path but! 
    # there is the opportunity to have the 'cleric' join the party
  print("Her golden eyes lock with the bracelet.")
  print("She huffs and you feel oddly refreshed.\nThe bracelet clinks onto her wrist and a sigh of relief escapes her.\nYou beckon her to your side and she nods solemnly.")
    city_path1('\033[93m' + 'Penelope' + '\033[93m' '\033[0m' "the" '\033[1m' + 'Cleric' + '\033[0m' "has joined your party!")
  elif answer == "2":
    # the cleric does NOT joint the party
    # player continues on their journey
    print("Shaking your head with a fervent no.\nShe regards you coldly snarling, with a spin of her cloak she is gone.")
    city_path1()
  else:
    # call try_again() with "reason"
    try_again("Don't be silly adventurer, once more!")

# light path
def light_path():
  # '\n' is to print the line in a new line
  print("\nThe bright path blows a cool breeze on your cheek alongside its earth scent, beckoning you to enter.")
  print("The jingle of your backpack creates a soothing rhythm as you wonder along the path.")
  print("You spot a cloaked figure in the distance.")
  print("Do you approach them? (1 or 2)")
  print("1). Yes.")
  print("2). No.")

  # take input()
  answer = input(">")
  
  if answer == "1":
    # both answers regardless will continue the adventurer onto the coast_path!
    coast_path("Calling out to the stranger they turn to face you, the hooded figure grey skinned baring fangs, they give you an inquisitive look. “Good day traveller, where are you headed today?”")
  elif answer == "2":
    print("\nWithout offering them a second glance you continue walking. They turn to face you, their grey skin baring their fangs, stomping their wooden staff. Startled, you stop in your tracks. A booming voice says, “Good day traveller, where are you headed today?”")
    coast_path()
  else:
    # else call game_over() function with the "reason" argument
    try_again("Don't be silly adventurer, once more!")

# dark path 
def dark_path():
  # '\n' is to print the line in a new line
  print("\nThe dark path leads into a twisted thick of forest, the once chattering animals now silenced.")
  print("A twinkling bracelet at the root of a tree catches your eye.\nDo you pick up the bracelet?")
  print("1). Yes.")
  print("2). No.")

  # take input()
  answer = input(">")

  if answer == "1":
    # both answers will lead to the city_path
    city_path("The ornate golden bracelet jangles as it weighs heavy in your hands as you examine the many trinkets hanging off it.")
  elif answer == "2":
    # the player is dead, call game_over() with "reason"
    city_path("That bracelet probably belongs to someone, you decide to leave it to be found by its owner.")
  else:
    # try_again with "reason"
    try_again("Don't be silly adventurer, once more!")

# function to ask play again or not
def play_again():
  print("\nDo you want to try again? (y or n)")
  
  # convert the player's input to lower_case
  answer = input(">").lower()

  if "y" in answer:
    # if player typed "yes" or "y" start the game from the beginning
    start()
  else:
    # if user types anything besides "yes" or "y", exit() the program
    exit()

# try_again function accepts an argument called "reason"
def try_again(reason):
  # print the "reason" in a new line (\n)
  print("\n" + reason)
  print('\033[1m' + 'Try Again!' + '\033[0m')
  # ask player to play again or not by activating try_again() function
  try_again()

    def start():
  # give some prompts.
  print("\nWelcome, you have entered the world of " + '\033[4m' + 'Wrenfar' + '\033[4m''\033[0m' "!")
  print("The sun glows brightly and the sky smiles upon you, which road shall you take? (l or r)")
  
  # convert the player's input() to lower_case
  answer = input(">").lower()

  if "l" in answer:
    # if player typed "left" or "l" lead to the light path
    light_path()
  elif "r" in answer:
    # else if player typed "right" or "r" lead to the dark path
    dark_path()
  else:
    # else call try_again() function with the "reason" argument
    try_again("Don't be silly adventurer, once more!")

# start the adventure
start()
# Out:
#   File "/tmp/ipykernel_10947/1586365511.py", line 19
#     elif answer == "2":
#
# ^
# SyntaxError: invalid syntax
